# %%
import pandas as pd
import numpy as np

from sklearn.naive_bayes import GaussianNB 
from sklearn import metrics

# %%
df = pd.read_csv('data/data without infertility _final.csv', delimiter=',')#,skiprows=1)

# %%
# print(df.columns)
del df['AMH(ng/mL)']
del df['Unnamed: 42'] #All NaN value 
del df['Marraige Status (Yrs)'] #1 NaN value 
del df['Fast food (Y/N)'] #1 NaN value 

# print(df.isna().sum())

var = 0
for cols in df.columns:
    try:
        df[cols] = df[cols].astype(float)
        print(df[cols].isnull())
        var += 1
    except:
        print(var)
        break

train = df.sample(frac=0.50,random_state=42) #random state is a seed value
test = df.drop(train.index)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Sl. No, Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Patient File No., Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: PCOS (Y/N), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name:  Age (yrs), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Weight (Kg), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Height(Cm) , Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: BMI, Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Blood Group, Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Pulse rate(bpm) , Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: RR (breaths/min), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Hb(g/dl), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Cycle(R/I), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Cycle length(days), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Pregnant(Y/N), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: No. of aborptions, Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: FSH(mIU/mL), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: LH(mIU/mL), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: FSH/LH, Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Hip(inch), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Waist(inch), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Waist:Hip Ratio, Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: TSH (mIU/L), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: PRL(ng/mL), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Vit D3 (ng/mL), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: PRG(ng/mL), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: RBS(mg/dl), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Weight gain(Y/N), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: hair growth(Y/N), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Skin darkening (Y/N), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Hair loss(Y/N), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Pimples(Y/N), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Reg.Exercise(Y/N), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: BP _Systolic (mmHg), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: BP _Diastolic (mmHg), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Follicle No. (L), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Follicle No. (R), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Avg. F size (L) (mm), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Avg. F size (R) (mm), Length: 541, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: Endometrium (mm), Length: 541, dtype: bool

# %%
X_train = train.iloc[:,[var for var in range(2,df.shape[1])]].values
y_train = train.iloc[:,2].values

X_test = test.iloc[:,[var for var in range(2,df.shape[1])]].values
y_test = test.iloc[:,2].values

# %%
gnb = GaussianNB() 
gnb.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = gnb.predict(X_test) 
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 100.0
